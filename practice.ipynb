# %%
import time, requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

for i in range(10):
	r = requests.get('https://cataas.com/cat')
	img = Image.open(BytesIO(r.content))
	# img
	plt.figure()
	plt.imshow(img)

# %% [markdown]
# # Datetime

# %%
import datetime, calendar
import pytz

datetime.datetime.now(tz=pytz.UTC)

# print( pytz.timezone('Africa/Abidjan').localize(datetime.datetime.now()) )

hour   = datetime.datetime.now(tz=pytz.timezone('America/Merida')).hour
minute = datetime.datetime.now(tz=pytz.timezone('America/Merida')).minute
second = datetime.datetime.now(tz=pytz.timezone('America/Merida')).second

time = f"{hour}:{minute}:{second}"
time
# Out:
# '19:5:23'

# %% [markdown]
# # Schedule

# %%
import schedule
import time

def job():
    print("I'm working...")

schedule.every(2).seconds.do(job)


while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# I'm working...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\evgen\Desktop\Python\Telegrambot_Carolinas_bot\practice.ipynb Cell 4 in <cell line: 10>()
#      <a href='vscode-notebook-cell:/c%3A/Users/evgen/Desktop/Python/Telegrambot_Carolinas_bot/practice.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/evgen/Desktop/Python/Telegrambot_Carolinas_bot/practice.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>     schedule.run_pending()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/evgen/Desktop/Python/Telegrambot_Carolinas_bot/practice.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>     time.sleep(1)
#
# KeyboardInterrupt:

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('https://cataas.com/cat')

### Download image
# with open('check.png', 'wb') as f:
# 	f.write(r.content)

img = Image.open(BytesIO(r.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>
